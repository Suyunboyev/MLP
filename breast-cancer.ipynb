# %% [markdown]
# <a href="https://www.kaggle.com/code/olimsuyunboyev/breast-cancer?scriptVersionId=248321738" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import jaccard_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
url = "https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/breast-cancer.csv"
df = pd.read_csv(url)
df.sample(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 508  915452         B       16.300         15.70          104.70      819.8
# 40   855167         M       13.440         21.58           86.18      563.0
# 172   87164         M       15.460         11.89          102.50      736.9
# 550  923748         B       10.860         21.48           68.51      360.5
# 238  883270         B       14.220         27.85           92.55      623.9
# 333  897137         B       11.250         14.78           71.38      390.0
# 37   854941         B       13.030         18.42           82.61      523.8
# 103  862980         B        9.876         19.40           63.95      298.3
# 477  911673         B       13.900         16.62           88.97      599.4
# 108   86355         M       22.270         19.67          152.80     1509.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 508          0.09427           0.06712        0.055260             0.045630
# 40           0.08162           0.06031        0.031100             0.020310
# 172          0.12570           0.15550        0.203200             0.109700
# 550          0.07431           0.04227        0.000000             0.000000
# 238          0.08223           0.10390        0.110300             0.044080
# 333          0.08306           0.04458        0.000974             0.002941
# 37           0.08983           0.03766        0.025620             0.029230
# 103          0.10050           0.09697        0.061540             0.030290
# 477          0.06828           0.05319        0.022240             0.013390
# 108          0.13260           0.27680        0.426400             0.182300
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 508  ...         17.32          17.76           109.80       928.2
# 40   ...         15.93          30.25           102.50       787.9
# 172  ...         18.79          17.04           125.00      1102.0
# 550  ...         11.66          24.77            74.08       412.3
# 238  ...         15.75          40.54           102.50       764.0
# 333  ...         12.76          22.06            82.08       492.7
# 37   ...         13.30          22.81            84.46       545.9
# 103  ...         10.76          26.83            72.22       361.2
# 477  ...         15.14          21.80           101.20       718.9
# 108  ...         28.40          28.01           206.80      2360.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 508           0.13540            0.13610         0.194700
# 40            0.10940            0.20430         0.208500
# 172           0.15310            0.35830         0.583000
# 550           0.10010            0.07348         0.000000
# 238           0.10810            0.24260         0.306400
# 333           0.11660            0.09794         0.005518
# 37            0.09701            0.04619         0.048330
# 103           0.15590            0.23020         0.264400
# 477           0.09384            0.20060         0.138400
# 108           0.17010            0.69970         0.960800
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 508               0.13570          0.2300                  0.07230
# 40                0.11120          0.2994                  0.07146
# 172               0.18270          0.3216                  0.10100
# 550               0.00000          0.2458                  0.06592
# 238               0.08219          0.1890                  0.07796
# 333               0.01667          0.2815                  0.07418
# 37                0.05013          0.1987                  0.06169
# 103               0.09749          0.2622                  0.08490
# 477               0.06222          0.2679                  0.07698
# 108               0.29100          0.4055                  0.09789
#
# [10 rows x 32 columns]

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
label = LabelEncoder()
df['diagnosis'] = label.fit_transform(df['diagnosis'].values)
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
df.drop(columns=['id'], inplace=True)
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
corr_matrix = df.corr().abs()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_17a61_row0_col0, #T_17a61_row1_col1, #T_17a61_row1_col3, #T_17a61_row2_col2, #T_17a61_row3_col1, #T_17a61_row3_col3, #T_17a61_row4_col4, #T_17a61_row5_col5, #T_17a61_row6_col6, #T_17a61_row7_col7, #T_17a61_row8_col8, #T_17a61_row9_col9, #T_17a61_row10_col10, #T_17a61_row11_col11, #T_17a61_row12_col12, #T_17a61_row13_col13, #T_17a61_row14_col14, #T_17a61_row15_col15, #T_17a61_row16_col16, #T_17a61_row17_col17, #T_17a61_row18_col18, #T_17a61_row19_col19, #T_17a61_row20_col20, #T_17a61_row21_col21, #T_17a61_row22_col22, #T_17a61_row23_col23, #T_17a61_row24_col24, #T_17a61_row25_col25, #T_17a61_row26_col26, #T_17a61_row27_col27, #T_17a61_row28_col28, #T_17a61_row29_col29, #T_17a61_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_17a61_row0_
{
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_17a61_row0_col23, #T_17a61_row23_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_17a61_row0_col27, #T_17a61_row7_col13, #T_17a61_row8_col26 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_17a61_row0_col28 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_17a61_row0_col29, #T_17a61_row18_col4, #T_17a61_row19_col20 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_17a61_row0_col30, #T_17a61_row5_col18, #T_17a61_row10_col27, #T_17a61_row18_col15, #T_17a61_row22_col26 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_17a61_row1_col2, #T_17a61_row1_col18, #T_17a61_row2_col1, #T_17a61_row2_col4, #T_17a61_row4_col2, #T_17a61_row13_col16, #T_17a61_row30_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_17a61_row1_col4, #T_17a61_row3_col4, #T_17a61_row4_col1, #T_17a61_row4_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col5, #T_17a61_row10_col8, #T_17a61_row10_col28 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col6, #T_17a61_row5_col7, #T_17a61_row20_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_17a61_row1_col7, #T_17a61_row6_col5, #T_17a61_row17_col27, #T_17a61_row24_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_17a61_row1_col8, #T_17a61_row4_col8 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col9, #T_17a61_row2_col18, #T_17a61_row18_col22, #T_17a61_row26_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col10, #T_17a61_row25_col15 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_17a61_row1_col11, #T_17a61_row7_col21, #T_17a61_row9_col29, #T_17a61_row11_col1, #T_17a61_row29_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_17a61_row1_col12, #T_17a61_row4_col9, #T_17a61_row8_col19, #T_17a61_row9_col22, #T_17a61_row19_col24 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col13, #T_17a61_row21_col7 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_17a61_row1_col14, #T_17a61_row4_col11, #T_17a61_row11_col4, #T_17a61_row14_col1, #T_17a61_row24_col0 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_17a61_row1_col15, #T_17a61_row9_col23, #T_17a61_row13_col12, #T_17a61_row15_col1, #T_17a61_row15_col23, #T_17a61_row16_col25, #T_17a61_row22_col25, #T_17a61_row22_col30, #T_17a61_row30_col22 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col16, #T_17a61_row10_col14, #T_17a61_row15_col22, #T_17a61_row15_col28, #T_17a61_row20_col0, #T_17a61_row21_col16, #T_17a61_row22_col19, #T_17a61_row25_col2, #T_17a61_row29_col13, #T_17a61_row30_col19 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col17, #T_17a61_row12_col16, #T_17a61_row12_col17, #T_17a61_row14_col12, #T_17a61_row19_col23, #T_17a61_row21_col12, #T_17a61_row24_col19 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col19, #T_17a61_row12_col23, #T_17a61_row15_col30, #T_17a61_row19_col1, #T_17a61_row23_col19, #T_17a61_row24_col17, #T_17a61_row25_col16, #T_17a61_row29_col2, #T_17a61_row29_col15 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_17a61_row1_col20, #T_17a61_row12_col30, #T_17a61_row13_col10, #T_17a61_row20_col29 {
#   background-color

# %%
df.corrwith(df['diagnosis']).abs().sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# concave points_worst       0.793566
# perimeter_worst            0.782914
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# radius_mean                0.730029
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.596534
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.548236
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# fractal_dimension_se       0.077972
# smoothness_se              0.067016
# fractal_dimension_mean     0.012838
# texture_se                 0.008303
# symmetry_se                0.006522
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
x = df.drop('diagnosis', axis=1).values
y = df['diagnosis']

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
# train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=12)

# %%
# k-NN
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(x_test)

# %%
jaccard_score(y_test, y_predict)
# Out:
# 0.8958333333333334

# %%
sns.heatmap(confusion_matrix(y_test, y_predict), annot=True)
plt.show()

# %%
accuracy = accuracy_score(y_test, y_predict)
print("KNeighborsClassifier Accuracy: ", accuracy)
# Out:
# KNeighborsClassifier Accuracy:  0.956140350877193

# %%
f1 = []
for i in range(1, 25):
  knn = KNeighborsClassifier(n_neighbors=i)
  knn.fit(x_train, y_train)
  y_predict = knn.predict(x_test)
  f1.append(accuracy_score(y_test, y_predict))

plt.figure(figsize=(12, 6))
plt.plot(range(1, 25), f1)
plt.xticks(range(1, 25))
plt.grid()
plt.show()
